# %% [markdown]
# <a href="https://colab.research.google.com/github/Dichter-Jang/oulu/blob/main/MotionLCM_EEG_Control.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git clone https://github.com/Dai-Wenxun/MotionLCM.git
# %cd MotionLCM
# Out:
# /content
# fatal: destination path 'MotionLCM' already exists and is not an empty directory.
# /content/MotionLCM

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Using cached swanlab-0.7.6-py3-none-any.whl.metadata (44 kB)
# ...
#   Using cached torchmetrics-1.3.2-py3-none-any.whl.metadata (19 kB)
# ...
#   Using cached scipy-1.11.2-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (59 kB)
# ...
#   Using cached transformers-4.38.0-py3-none-any.whl.metadata (131 kB)
# ...
#   Using cached sentence-transformers-2.2.2.tar.gz (85 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached diffusers-0.24.0-py3-none-any.whl.metadata (18 kB)
# ...
#   Using cached tensorboard-2.15.1-py3-none-any.whl.metadata (1.7 kB)
# ...
#   Using cached huggingface_hub-0.25.0-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached h5py-3.11.0-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.5 kB)
# ...
#   Using cached smplx-0.1.28-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached chumpy-0.70.tar.gz (50 kB)
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.8 MB/s eta 0:00:00
# ...

# %%
# !sudo apt-get update -y
# !sudo apt-get install -y ffmpeg git-lfs
# !git lfs install
# Out:
# Hit:1 https://cli.github.com/packages stable InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:4 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:6 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# ...

# %%
# !bash prepare/download_glove.sh
# !bash prepare/download_t2m_evaluators.sh
# !bash prepare/prepare_t5.sh
# !bash prepare/download_smpl_models.sh
# Out:
# ...
# Downloading...
# From: https://drive.google.com/uc?id=1cmXKUT31pqd7_XpJAiWEo1K81TMYHA5n
# To: /content/MotionLCM/deps/glove.zip
# 100% 6.19M/6.19M [00:00<00:00, 69.4MB/s]
# Archive:  glove.zip
#    creating: glove/
#   inflating: glove/our_vab_idx.pkl
#   inflating: glove/our_vab_data.npy
#   inflating: glove/our_vab_words.pkl
# Cleaning
#
# ...
# The t2m evaluators will be stored in the './deps' folder
# Downloading
# Downloading...
# From (original): https://drive.google.com/uc?id=16hyR4XlEyksVyNVjhIWK684Lrm_7_pvX
# From (redirected): https://drive.google.com/uc?id=16hyR4XlEyksVyNVjhIWK684Lrm_7_pvX&confirm=t&uuid=7eb18c63-12f5-4649-8b64-5e340c4b8a7d
# To: /content/MotionLCM/deps/t2m.zip
# 100% 453M/453M [00:06<00:00, 72.3MB/s]
# Extracting
# Archive:  t2m.zip
#    creating: t2m/kit/
#    creating: t2m/kit/Comp_v6_KLD005/
#    creating: t2m/kit/Comp_v6_KLD005/meta/
#   inflating: t2m/kit/Comp_v6_KLD005/meta/mean.npy
#   inflating: t2m/kit/Comp_v6_KLD005/meta/std.npy
# ...

# %%
# !bash prepare/download_pretrained_models.sh
# !bash prepare/prepare_tiny_humanml3d.sh
# Out:
# ...
# Downloading...
# From (original): https://drive.google.com/uc?id=15zFDitcOLhjbQ0CaOoM-QNKQUeyJw-Om
# From (redirected): https://drive.google.com/uc?id=15zFDitcOLhjbQ0CaOoM-QNKQUeyJw-Om&confirm=t&uuid=74c8fb61-fda1-4d7f-8892-5ccfbd385f67
# To: /content/MotionLCM/experiments_recons.zip
# 100% 148M/148M [00:00<00:00, 169MB/s]
# Archive:  experiments_recons.zip
#    creating: experiments_recons/
#    creating: experiments_recons/vae_humanml/
#   inflating: experiments_recons/vae_humanml/vae_humanml.ckpt
# ...
# Downloading...
# From (original): https://drive.google.com/uc?id=1U7homKobR2gaDLfL5flS3N0g7e0a_AQd
# From (redirected): https://drive.google.com/uc?id=1U7homKobR2gaDLfL5flS3N0g7e0a_AQd&confirm=t&uuid=d54e2848-98eb-4e97-a607-701696cf1830
# To: /content/MotionLCM/experiments_t2m.zip
# 100% 714M/714M [00:03<00:00, 181MB/s]
# Archive:  experiments_t2m.zip
#    creating: experiments_t2m/
#    creating: experiments_t2m/mld_humanml/
#   inflating: experiments_t2m/mld_humanml/mld_humanml.ckpt
# ...

# %%
# !python demo.py --cfg configs/vae.yaml
# Out:
# 01/11/2026 22:56:25 - INFO - __main__ - Loading checkpoints from experiments_recons/vae_humanml/vae_humanml.ckpt
# 01/11/2026 22:56:25 - INFO - __main__ - Is VAE: True
# 01/11/2026 22:56:25 - INFO - __main__ - Is MLD: False
# 01/11/2026 22:56:25 - INFO - __main__ - Is LCM: False
# 01/11/2026 22:56:25 - INFO - __main__ - Is Controlnet: False
# 01/11/2026 22:56:26 - INFO - mld.models.modeltype.vae - latent_dim: [16, 32]
# 01/11/2026 22:56:26 - INFO - mld.models.modeltype.vae - rec_feats_ratio: 1.0, rec_joints_ratio: 1.0, rec_velocity_ratio: 0.0, kl_ratio: 0.0001
# 01/11/2026 22:56:26 - INFO - mld.models.modeltype.vae - rec_feats_loss: l1_smooth, rec_joints_loss: l1_smooth, rec_velocity_loss: l1_smooth
# 01/11/2026 22:56:26 - INFO - mld.models.modeltype.vae - mask_loss: True
# 01/11/2026 22:56:26 - INFO - mld.models.modeltype.vae - VAE Encoder: 7.634M
# 01/11/2026 22:56:26 - INFO - mld.models.modeltype.vae - VAE Decoder: 10.007M
# ...

# %%
from IPython.display import Video, display

display(Video("./experiments_recons_test/vae_humanml/demo_2026-01-11T22-56-25/samples/batch_id_0_sample_id_0_length_132_rep_0.mp4", embed=True))
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# !python demo.py --cfg configs/mld_t2m.yaml --example assets/example.txt
# !python demo.py --cfg configs/motionlcm_t2m.yaml --example assets/example.txt
# Out:
# 01/11/2026 22:59:45 - INFO - __main__ - Loading checkpoints from experiments_t2m/mld_humanml/mld_humanml.ckpt
# 01/11/2026 22:59:45 - INFO - __main__ - Is VAE: True
# 01/11/2026 22:59:45 - INFO - __main__ - Is MLD: True
# 01/11/2026 22:59:45 - INFO - __main__ - Is LCM: False
# 01/11/2026 22:59:45 - INFO - __main__ - Is Controlnet: False
# 01/11/2026 22:59:47 - INFO - numexpr.utils - NumExpr defaulting to 2 threads.
# 01/11/2026 22:59:48 - INFO - sentence_transformers.SentenceTransformer - Load pretrained SentenceTransformer: ./deps/sentence-t5-large
# 01/11/2026 22:59:52 - INFO - sentence_transformers.SentenceTransformer - Use pytorch device: cuda
# /usr/local/lib/python3.12/dist-packages/diffusers/utils/outputs.py:63: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   torch.utils._pytree._register_pytree_node(
# 01/11/2026 22:59:56 - INFO - mld.models.modeltype.mld - vae_scale_factor: 1.0
# ...

# %%
from IPython.display import Video, display

display(Video("./experiments_t2m_test/motionlcm_humanml/demo_2026-01-11T23-00-23/samples/sample_id_2_length_56_rep_0.mp4", embed=True))
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# !python demo.py --cfg configs/mld_t2m.yaml
# !python demo.py --cfg configs/motionlcm_t2m.yaml
# Out:
# 01/11/2026 23:00:49 - INFO - __main__ - Loading checkpoints from experiments_t2m/mld_humanml/mld_humanml.ckpt
# 01/11/2026 23:00:49 - INFO - __main__ - Is VAE: True
# 01/11/2026 23:00:49 - INFO - __main__ - Is MLD: True
# 01/11/2026 23:00:49 - INFO - __main__ - Is LCM: False
# 01/11/2026 23:00:49 - INFO - __main__ - Is Controlnet: False
# 01/11/2026 23:00:49 - INFO - numexpr.utils - NumExpr defaulting to 2 threads.
# 01/11/2026 23:00:50 - INFO - sentence_transformers.SentenceTransformer - Load pretrained SentenceTransformer: ./deps/sentence-t5-large
# 01/11/2026 23:00:51 - INFO - sentence_transformers.SentenceTransformer - Use pytorch device: cuda
# /usr/local/lib/python3.12/dist-packages/diffusers/utils/outputs.py:63: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   torch.utils._pytree._register_pytree_node(
# 01/11/2026 23:00:53 - INFO - mld.models.modeltype.mld - vae_scale_factor: 1.0
# ...

# %%
from IPython.display import Video, display

display(Video("./experiments_t2m_test/motionlcm_humanml/demo_2026-01-11T23-01-37/samples/batch_id_0_sample_id_4_length_196_rep_0_ref.mp4", embed=True))
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# !python demo.py --cfg configs/motionlcm_control_s.yaml
# Out:
# 01/11/2026 23:02:28 - INFO - __main__ - Loading checkpoints from experiments_control/spatial/motionlcm_humanml/motionlcm_humanml_s_pelvis.ckpt
# 01/11/2026 23:02:28 - INFO - __main__ - Is VAE: True
# 01/11/2026 23:02:28 - INFO - __main__ - Is MLD: True
# 01/11/2026 23:02:28 - INFO - __main__ - Is LCM: True
# 01/11/2026 23:02:28 - INFO - __main__ - Is Controlnet: True
# 01/11/2026 23:02:28 - INFO - mld.models.modeltype.mld - Guidance Scale set as 8.0
# 01/11/2026 23:02:29 - INFO - numexpr.utils - NumExpr defaulting to 2 threads.
# 01/11/2026 23:02:29 - INFO - sentence_transformers.SentenceTransformer - Load pretrained SentenceTransformer: ./deps/sentence-t5-large
# 01/11/2026 23:02:30 - INFO - sentence_transformers.SentenceTransformer - Use pytorch device: cuda
# /usr/local/lib/python3.12/dist-packages/diffusers/utils/outputs.py:63: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
# ...

# %%
from IPython.display import Video, display

display(Video("./experiments_control_test/spatial/motionlcm_humanml/demo_2026-01-11T23-02-27/samples/batch_id_0_sample_id_4_length_64_rep_0_ref.mp4", embed=True))
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
# !python demo.py --cfg configs/motionlcm_t2m_clt.yaml --optimize
# Out:
# 01/11/2026 23:03:49 - INFO - __main__ - Loading checkpoints from experiments_t2m/motionlcm_humanml/motionlcm_humanml.ckpt
# 01/11/2026 23:03:49 - INFO - __main__ - Is VAE: True
# 01/11/2026 23:03:49 - INFO - __main__ - Is MLD: True
# 01/11/2026 23:03:49 - INFO - __main__ - Is LCM: True
# 01/11/2026 23:03:49 - INFO - __main__ - Is Controlnet: False
# 01/11/2026 23:03:49 - INFO - __main__ - Optimization enabled. Set the batch size to 1.
# 01/11/2026 23:03:49 - INFO - __main__ - Original batch size: 1
# 01/11/2026 23:03:49 - INFO - mld.models.modeltype.mld - Guidance Scale set as 8.0
# 01/11/2026 23:03:49 - INFO - numexpr.utils - NumExpr defaulting to 2 threads.
# 01/11/2026 23:03:50 - INFO - sentence_transformers.SentenceTransformer - Load pretrained SentenceTransformer: ./deps/sentence-t5-large
# 01/11/2026 23:03:51 - INFO - sentence_transformers.SentenceTransformer - Use pytorch device: cuda
# ...

# %%
from IPython.display import Video, display

display(Video("./experiments_t2m_test/motionlcm_humanml/demo_2026-01-11T23-03-48/samples/batch_id_4_sample_id_0_length_192_rep_0_ref.mp4", embed=True))
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
